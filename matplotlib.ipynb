# %% [markdown]
# <a href="https://colab.research.google.com/github/yamaniyuda/Scientific-Computation/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Itrodaction Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

'''
  1.  Create data
  2.  Create plot
  3.  Show plot
'''

# 1.  Create data
x = np.array([1,2,3,4,5])
y = x ** 2
y2 = x ** 3

# 2.  Create plot
plt.plot(x,y)
plt.plot(x,y2)

# 3.  Show plot
plt.show()

# %% [markdown]
# # Set color and Marker

# %%
import numpy as np
import matplotlib.pyplot as plt

'''
  1.  Create data
  2.  Create plot
  3.  Show plot
'''

# 1.  Create data (sin(2wt + theta))
def sinusGenerator(amplitudo, frekuensi, tLast, theta):
  t = np.arange(0, tLast, 0.1)
  y = amplitudo * np.sin(2 * frekuensi * t + np.deg2rad(theta))
  return t, y

fig, (plt1, plt2) = plt.subplots(1, 2)

# 2.  Create plot sinus generator
plt1.set_title('Sinus Generator')
t1, y1 = sinusGenerator(1, 1, 4, 0)
plt1.plot(t1, y1)
t2, y2 = sinusGenerator(1, 1, 4, 90)
plt1.plot(t2, y2, 'b-o')

# circle
radius = 5
engle = np.arange(0, 2*np.pi, 0.1)
x = radius * np.cos(engle)
y = radius * np.sin(engle)
plt2.set_title('Circle')
plt2.plot(x, y)

# 3.  Show plot
plt.show()

# %% [markdown]
# # Set Label and Title

# %%
import numpy as np
import matplotlib.pyplot as plt

'''
  1.  Create data
  2.  Create plot
  3.  Show plot
'''

# 1.  Create data (sin(2wt + theta))
def sinusGenerator(amplitudo, frekuensi, tLast, theta):
  t = np.arange(0, tLast, 0.1)
  y = amplitudo * np.sin(2 * frekuensi * t + np.deg2rad(theta))
  return t, y

amplitudo = 1
frekuensi = 1
theta = 0
tlast = 4

t,y = sinusGenerator(amplitudo, frekuensi, tlast, theta)

title = 'Grafik Sinusodial\n'
formula = r'$ \mathcal{Y} = A.sin(2 \omega t + \theta) $' + '\n'
params1 = r'$ A = $' + str(amplitudo) + ' cm, '
params2 = r'$ \omega = $' + str(frekuensi) + r'$ \mathit{Hz} $' + ', '
params3 = r'$ \theta = $' + str(theta) + r'$ ^{o} $'

plt.plot(t,y)
plt.title(title + formula + params1 + params2 + params3)
plt.xlabel('waktu(detik)')
plt.ylabel('magnituda(cm)')

plt.show()

# %% [markdown]
# # Create Legend

# %%
import numpy as np
import matplotlib.pyplot as plt

'''
  1.  Create data
  2.  Create plot
  3.  Show plot
'''

# 1.  Create data (sin(2wt + theta))
def sinusGenerator(amplitudo, frekuensi, tLast, theta):
  t = np.arange(0, tLast, 0.1)
  y = amplitudo * np.sin(2 * frekuensi * t + np.deg2rad(theta))
  return t, y

amplitudo = 1
frekuensi = 1
theta = 0
tlast = 4

t,y = sinusGenerator(amplitudo, frekuensi, tlast, theta)

title = 'Grafik Sinusodial\n'
formula = r'$ \mathcal{Y} = A.sin(2 \omega t + \theta) $' + '\n'
params1 = r'$ A = $' + str(amplitudo) + ' cm, '
params2 = r'$ \omega = $' + str(frekuensi) + r'$ \mathit{Hz} $' + ', '
params3 = r'$ \theta = $' + str(theta) + r'$ ^{o} $'

plt.plot(t,y, label="sin(0)")
plt.title(title + formula + params1 + params2 + params3)
plt.xlabel('waktu(detik)')
plt.ylabel('magnituda(cm)')
plt.legend(loc = "upper center", bbox_to_anchor = (1.2, 1))

# Create legend and move plot
plt.figure(1)
ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.7, box.height])



plt.show()
